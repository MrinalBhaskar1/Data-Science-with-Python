# %%
import pandas as pd

# %%
26Mar
X.head(),X.head(10),
X.tail(),X.tail(10),
X.describe(),X.info(),X.corr(),X.std(),X.var(),X.medium(),X.mode(),
X.shape,X.shape[0],X.shape[1],
X.columns,X.Col_nam,X['Col_nam'], Col_nam is name of column
X['new_Col']=X['Col1']-X['Col2'],X.New_Col=X.Col1-X.Col2, new_Col is new column and Col1 and COl2 is name of column
Smp=X.sample(n=10),Smp=X.sample(frac=0.5),
Smp.head(),Smp.shape,X.iloc[:,:],
X.Col.mean(),X.Col.min(),X.Col.max(),X.Col.describe(),X.Col.count(),/X.Col.value_counts(),X['Col'].value_counts()/,X.Col.unique(),X.Col.hist(), Col is name of column
type(X),V=X.iloc[3,4],type(V),
X.groupby(X.Col).mean(),X.groupby(X.Col).mean(),X[X.Col>8], Col is name of column
date=pd.date_range('20150101',period=6),
import np,
df=pd.DataFrame(np.random.randn(6,4),index=date,columns=list('ABCD')),
df.loc[date[0]],df.loc[:,['A','B']],df.loc['20130201':'20130205',['A','B']],df[df.A>0].ipynb

# %%
cd
# Out:
# C:\Users\HP

# %%
cd downloads
# Out:
# C:\Users\HP\downloads

# %%
pd.read_csv("mrinal.csv")
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2018                     Level 1                99999
# 1      2018                     Level 1                99999
# 2      2018                     Level 1                99999
# 3      2018                     Level 1                99999
# 4      2018                     Level 1                99999
# ...     ...                         ...                  ...
# 27805  2013                     Level 3                 ZZ11
# 27806  2013                     Level 3                 ZZ11
# 27807  2013                     Level 3                 ZZ11
# 27808  2013                     Level 3                 ZZ11
# 27809  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
coe=pd.read_csv('mrinal.csv')

# %%
coe
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2018                     Level 1                99999
# 1      2018                     Level 1                99999
# 2      2018                     Level 1                99999
# 3      2018                     Level 1                99999
# 4      2018                     Level 1                99999
# ...     ...                         ...                  ...
# 27805  2013                     Level 3                 ZZ11
# 27806  2013                     Level 3                 ZZ11
# 27807  2013                     Level 3                 ZZ11
# 27808  2013                     Level 3                 ZZ11
# 27809  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
coe.head() #printing 5 element of table
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2018                     Level 1                99999       All industries
# 1  2018                     Level 1                99999       All industries
# 2  2018                     Level 1                99999       All industries
# 3  2018                     Level 1                99999       All industries
# 4  2018                     Level 1                99999       All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# 1  Dollars (millions)           H04
# 2  Dollars (millions)           H05
# 3  Dollars (millions)           H07
# 4  Dollars (millions)           H08
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# 1  Sales, government funding, grants and subsidies  Financial performance
# ...

# %%
coe.head(10) #printing top 10 element
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2018                     Level 1                99999       All industries
# 1  2018                     Level 1                99999       All industries
# 2  2018                     Level 1                99999       All industries
# 3  2018                     Level 1                99999       All industries
# 4  2018                     Level 1                99999       All industries
# 5  2018                     Level 1                99999       All industries
# 6  2018                     Level 1                99999       All industries
# 7  2018                     Level 1                99999       All industries
# 8  2018                     Level 1                99999       All industries
# 9  2018                     Level 1                99999       All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# ...

# %%
coe.tail() #printing lowest 5 element
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 27805  2013                     Level 3                 ZZ11
# 27806  2013                     Level 3                 ZZ11
# 27807  2013                     Level 3                 ZZ11
# 27808  2013                     Level 3                 ZZ11
# 27809  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC       Units Variable_code  \
# 27805  Food product manufacturing  Percentage           H37
# 27806  Food product manufacturing  Percentage           H38
# 27807  Food product manufacturing  Percentage           H39
# 27808  Food product manufacturing  Percentage           H40
# 27809  Food product manufacturing  Percentage           H41
#
#                              Variable_name Variable_category Value  \
# 27805                          Quick ratio  Financial ratios    52
# 27806  Margin on sales of goods for resale  Financial ratios    40
# ...

# %%
coe.tail(10)
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 27800  2013                     Level 3                 ZZ11
# 27801  2013                     Level 3                 ZZ11
# 27802  2013                     Level 3                 ZZ11
# 27803  2013                     Level 3                 ZZ11
# 27804  2013                     Level 3                 ZZ11
# 27805  2013                     Level 3                 ZZ11
# 27806  2013                     Level 3                 ZZ11
# 27807  2013                     Level 3                 ZZ11
# 27808  2013                     Level 3                 ZZ11
# 27809  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 27800  Food product manufacturing  Dollars (millions)           H32
# 27801  Food product manufacturing  Dollars (millions)           H33
# 27802  Food product manufacturing             Dollars           H34
# ...

# %%
 coe.describe() # describes about the info of the file
# Out:
#                Year
# count  27810.000000
# mean    2015.500000
# std        1.707856
# min     2013.000000
# 25%     2014.000000
# 50%     2015.500000
# 75%     2017.000000
# max     2018.000000

# %%
coe.info() print all row s of the file
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27810 entries, 0 to 27809
# Data columns (total 10 columns):
# Year                           27810 non-null int64
# Industry_aggregation_NZSIOC    27810 non-null object
# Industry_code_NZSIOC           27810 non-null object
# Industry_name_NZSIOC           27810 non-null object
# Units                          27810 non-null object
# Variable_code                  27810 non-null object
# Variable_name                  27810 non-null object
# Variable_category              27810 non-null object
# Value                          27810 non-null object
# Industry_code_ANZSIC06         27810 non-null object
# dtypes: int64(1), object(9)
# memory usage: 2.1+ MB

# %%
coe.shape # print count of rows and calumn
# Out:
# (27810, 10)

# %%
coe.shape[0]
# Out:
# 27810

# %%
coe.shape[1]
# Out:
# 10

# %%
coel=pd.read_csv("rio.csv") #i do not know why thisis in error
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-26-ad9fd7208a77> in <module>
# ----> 1 coel=pd.read_csv("rio.csv")
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
# ...

# %%
 coel=pd.read_excel("rio.xlsx")

# %%
coel.head()
# Out:
#    OrderDate   Region      Rep    Item  Units  Unit Cost   Total
# 0 2018-01-06     East    Jones  Pencil     95       1.99  189.05
# 1 2018-01-23  Central   Kivell  Binder     50      19.99  999.50
# 2 2018-02-09  Central  Jardine  Pencil     36       4.99  179.64
# 3 2018-02-26  Central     Gill     Pen     27      19.99  539.73
# 4 2018-03-15     West  Sorvino  Pencil     56       2.99  167.44

# %%
coel.columns #column of table
# Out:
# Index(['OrderDate', 'Region', 'Rep', 'Item', 'Units', 'Unit Cost', 'Total'], dtype='object')

# %%
coe.columns
# Out:
# Index(['Year', 'Industry_aggregation_NZSIOC', 'Industry_code_NZSIOC',
#        'Industry_name_NZSIOC', 'Units', 'Variable_code', 'Variable_name',
#        'Variable_category', 'Value', 'Industry_code_ANZSIC06'],
#       dtype='object')

# %%
coel.Total  #coe.year is an error (becasue python is case sensitive)
# Out:
# 0      189.05
# 1      999.50
# 2      179.64
# 3      539.73
# 4      167.44
# 5      299.40
# 6      149.25
# 7      449.10
# 8       63.68
# 9      539.40
# 10     449.10
# 11      57.71
# 12    1619.19
# 13     174.65
# 14     250.00
# 15     255.84
# 16     251.72
# 17     575.36
# 18     299.85
# 19     479.04
# 20      86.43
# 21    1183.26
# 22     413.54
# 23    1305.00
# 24      19.96
# 25     139.93
# 26     249.50
# 27     131.34
# 28     479.04
# 29      68.37
# 30     719.20
# 31     625.00
# 32     309.38
# 33     686.95
# 34    1005.90
# 35     825.00
# 36       9.03
# 37     151.24
# 38    1139.43
# 39      18.06
# 40      54.89
# 41    1879.06
# 42     139.72
# Name: Total, dtype: float64

# %%
coel['Units']
# Out:
# 0     95
# 1     50
# 2     36
# 3     27
# 4     56
# 5     60
# 6     75
# 7     90
# 8     32
# 9     60
# 10    90
# 11    29
# 12    81
# 13    35
# 14     2
# 15    16
# 16    28
# 17    64
# 18    15
# 19    96
# 20    67
# 21    74
# 22    46
# 23    87
# 24     4
# 25     7
# 26    50
# 27    66
# 28    96
# 29    53
# 30    80
# 31     5
# 32    62
# 33    55
# 34    42
# 35     3
# 36     7
# 37    76
# 38    57
# 39    14
# 40    11
# 41    94
# 42    28
# Name: Units, dtype: int64

# %%
coel['Units']
# Out:
# 0     95
# 1     50
# 2     36
# 3     27
# 4     56
# 5     60
# 6     75
# 7     90
# 8     32
# 9     60
# 10    90
# 11    29
# 12    81
# 13    35
# 14     2
# 15    16
# 16    28
# 17    64
# 18    15
# 19    96
# 20    67
# 21    74
# 22    46
# 23    87
# 24     4
# 25     7
# 26    50
# 27    66
# 28    96
# 29    53
# 30    80
# 31     5
# 32    62
# 33    55
# 34    42
# 35     3
# 36     7
# 37    76
# 38    57
# 39    14
# 40    11
# 41    94
# 42    28
# Name: Units, dtype: int64

# %%
coel['new1_col']=coel['Total']-coel['Units']

# %%
coel.new2_col=coel.Total-coel.Units

# %%
coel
# Out:
#     OrderDate   Region       Rep     Item  Units  Unit Cost    Total  new_col  \
# 0  2018-01-06     East     Jones   Pencil     95       1.99   189.05    94.05
# 1  2018-01-23  Central    Kivell   Binder     50      19.99   999.50   949.50
# 2  2018-02-09  Central   Jardine   Pencil     36       4.99   179.64   143.64
# 3  2018-02-26  Central      Gill      Pen     27      19.99   539.73   512.73
# 4  2018-03-15     West   Sorvino   Pencil     56       2.99   167.44   111.44
# 5  2018-04-01     East     Jones   Binder     60       4.99   299.40   239.40
# 6  2018-04-18  Central   Andrews   Pencil     75       1.99   149.25    74.25
# 7  2018-05-05  Central   Jardine   Pencil     90       4.99   449.10   359.10
# 8  2018-05-22     West  Thompson   Pencil     32       1.99    63.68    31.68
# 9  2018-06-08     East     Jones   Binder     60       8.99   539.40   479.40
# 10 2018-06-25  Central    Morgan   Pencil     90       4.99   449.10   359.10
# ...

# %%
sample_coel=coel.sample(n=10)

# %%
sample_coel.head()
# Out:
#     OrderDate   Region     Rep     Item  Units  Unit Cost    Total  new_col  \
# 36 2019-09-10  Central    Gill   Pencil      7       1.29     9.03     2.03
# 34 2019-08-07  Central  Kivell  Pen Set     42      23.95  1005.90   963.90
# 20 2018-12-12  Central   Smith   Pencil     67       1.29    86.43    19.43
# 0  2018-01-06     East   Jones   Pencil     95       1.99   189.05    94.05
# 29 2019-05-14  Central    Gill   Pencil     53       1.29    68.37    15.37
#
#     new1_col  new2_col
# 36      2.03      2.03
# 34    963.90    963.90
# 20     19.43     19.43
# 0      94.05     94.05
# 29     15.37     15.37

# %%
sample_coel.shape
# Out:
# (10, 10)

# %%
sample_coel=coel.sample(frac=0.5)

# %%
sample_coel
# Out:
#     OrderDate   Region      Rep     Item  Units  Unit Cost    Total  new_col  \
# 27 2019-04-10  Central  Andrews   Pencil     66       1.99   131.34    65.34
# 35 2019-08-24     West  Sorvino     Desk      3     275.00   825.00   822.00
# 39 2019-10-31  Central  Andrews   Pencil     14       1.29    18.06     4.06
# 0  2018-01-06     East    Jones   Pencil     95       1.99   189.05    94.05
# 1  2018-01-23  Central   Kivell   Binder     50      19.99   999.50   949.50
# 13 2018-08-15     East    Jones   Pencil     35       4.99   174.65   139.65
# 3  2018-02-26  Central     Gill      Pen     27      19.99   539.73   512.73
# 6  2018-04-18  Central  Andrews   Pencil     75       1.99   149.25    74.25
# 24 2019-02-18     East    Jones   Binder      4       4.99    19.96    15.96
# 33 2019-07-21  Central   Morgan  Pen Set     55      12.49   686.95   631.95
# 7  2018-05-05  Central  Jardine   Pencil     90       4.99   449.10   359.10
# ...

# %%
sample_coel.shape
# Out:
# (22, 10)

# %%
sample_coel.iloc[:,:]
# Out:
#     OrderDate   Region      Rep     Item  Units  Unit Cost    Total  new_col  \
# 27 2019-04-10  Central  Andrews   Pencil     66       1.99   131.34    65.34
# 35 2019-08-24     West  Sorvino     Desk      3     275.00   825.00   822.00
# 39 2019-10-31  Central  Andrews   Pencil     14       1.29    18.06     4.06
# 0  2018-01-06     East    Jones   Pencil     95       1.99   189.05    94.05
# 1  2018-01-23  Central   Kivell   Binder     50      19.99   999.50   949.50
# 13 2018-08-15     East    Jones   Pencil     35       4.99   174.65   139.65
# 3  2018-02-26  Central     Gill      Pen     27      19.99   539.73   512.73
# 6  2018-04-18  Central  Andrews   Pencil     75       1.99   149.25    74.25
# 24 2019-02-18     East    Jones   Binder      4       4.99    19.96    15.96
# 33 2019-07-21  Central   Morgan  Pen Set     55      12.49   686.95   631.95
# 7  2018-05-05  Central  Jardine   Pencil     90       4.99   449.10   359.10
# ...

# %%
coel.Units.mean()
# Out:
# 49.325581395348834

# %%
coel.Units.min()
# Out:
# 2

# %%
coel.Units.max()
# Out:
# 96

# %%
 coel.Units.describe()
# Out:
# count    43.000000
# mean     49.325581
# std      30.078248
# min       2.000000
# 25%      27.500000
# 50%      53.000000
# 75%      74.500000
# max      96.000000
# Name: Units, dtype: float64

# %%
coel.Units.count()
# Out:
# 43

# %%
coel.Region.value_counts()
# Out:
# Central    24
# East       13
# West        6
# Name: Region, dtype: int64

# %%
coel.Region.unique()
# Out:
# array(['East', 'Central', 'West'], dtype=object)

# %%
coel.Units.hist()

# %%
type(coel)
# Out:
# pandas.core.frame.DataFrame

# %%
value=coel.iloc[3,4]

# %%
type(value)
# Out:
# numpy.int64

# %%
coel.std()
# Out:
# Units         30.078248
# Unit Cost     47.345118
# Total        447.022104
# dtype: float64

# %%
coel.mean()
# Out:
# Units         49.325581
# Unit Cost     20.308605
# Total        456.462326
# dtype: float64

# %%
coel.var()
# Out:
# Units           904.700997
# Unit Cost      2241.560169
# Total        199828.761323
# dtype: float64

# %%
coel.median()
# Out:
# Units         53.00
# Unit Cost      4.99
# Total        299.40
# dtype: float64

# %%
coel.mode()
# Out:
#     OrderDate   Region    Rep    Item  Units  Unit Cost   Total
# 0  2018-01-06  Central  Jones  Binder    7.0       4.99  449.10
# 1  2018-01-23      NaN    NaN     NaN   28.0        NaN  479.04
# 2  2018-02-09      NaN    NaN     NaN   50.0        NaN     NaN
# 3  2018-02-26      NaN    NaN     NaN   60.0        NaN     NaN
# 4  2018-03-15      NaN    NaN     NaN   90.0        NaN     NaN
# 5  2018-04-01      NaN    NaN     NaN   96.0        NaN     NaN
# 6  2018-04-18      NaN    NaN     NaN    NaN        NaN     NaN
# 7  2018-05-05      NaN    NaN     NaN    NaN        NaN     NaN
# 8  2018-05-22      NaN    NaN     NaN    NaN        NaN     NaN
# 9  2018-06-08      NaN    NaN     NaN    NaN        NaN     NaN
# 10 2018-06-25      NaN    NaN     NaN    NaN        NaN     NaN
# 11 2018-07-12      NaN    NaN     NaN    NaN        NaN     NaN
# 12 2018-07-29      NaN    NaN     NaN    NaN        NaN     NaN
# 13 2018-08-15      NaN    NaN     NaN    NaN        NaN     NaN
# ...

# %%
coel.groupby(coel.Region).mean()
# Out:
#              Units  Unit Cost       Total
# Region
# Central  49.958333  18.018750  464.127917
# East     53.153846   9.143846  461.699231
# West     38.500000  53.658333  414.453333

# %%
coel.groupby(coel.Item).mean()
# Out:
#              Units   Unit Cost       Total
# Item
# Binder   48.133333   11.524000  638.510000
# Desk      3.333333  175.000000  566.666667
# Pen      55.600000   11.190000  409.044000
# Pen Set  56.428571   11.912857  595.695714
# Pencil   55.076923    2.774615  164.241538

# %%
date=pd.date_range('20120101',periods=6)

# %%
date
# Out:
# DatetimeIndex(['2012-01-01', '2012-01-02', '2012-01-03', '2012-01-04',
#                '2012-01-05', '2012-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
import numpy as np

# %%
df=pd.DataFrame(np.random.randn(6,4), index=date, columns=list('ABCD'))

# %%
df
# Out:
#                    1         2         3         4
# 2012-01-01  1.701044 -1.012443 -0.353242  2.068383
# 2012-01-02  1.254450 -0.048052 -0.041940 -1.549058
# 2012-01-03  1.310125 -0.171058  0.356654 -0.169835
# 2012-01-04  0.400925 -1.897213 -0.716289  0.022766
# 2012-01-05  1.895656  1.229215  1.706537 -1.934505
# 2012-01-06 -0.406715  1.443649  1.594003  1.239361

# %%
df.loc[date[0]]
# Out:
# 1    1.701044
# 2   -1.012443
# 3   -0.353242
# 4    2.068383
# Name: 2012-01-01 00:00:00, dtype: float64

# %%
df.loc[:,['A','B']]
# Out:
#                    A         B
# 2012-01-01  0.567307 -2.294988
# 2012-01-02 -1.174171  0.279342
# 2012-01-03  2.014543  0.934096
# 2012-01-04  2.062120  0.464300
# 2012-01-05 -0.094258 -1.570287
# 2012-01-06  1.281773  1.294311

# %%
df.loc['20120102':'20120105',['A','B']]
# Out:
#                    A         B
# 2012-01-02 -1.174171  0.279342
# 2012-01-03  2.014543  0.934096
# 2012-01-04  2.062120  0.464300
# 2012-01-05 -0.094258 -1.570287

# %%
df.loc['20120102':'20120104',['A','B','C']]
# Out:
#                    A         B         C
# 2012-01-02 -1.174171  0.279342  0.495149
# 2012-01-03  2.014543  0.934096  0.462345
# 2012-01-04  2.062120  0.464300 -1.010371

# %%
coel[coel.Units>60]
# Out:
#     OrderDate   Region      Rep     Item  Units  Unit Cost    Total
# 0  2018-01-06     East    Jones   Pencil     95       1.99   189.05
# 6  2018-04-18  Central  Andrews   Pencil     75       1.99   149.25
# 7  2018-05-05  Central  Jardine   Pencil     90       4.99   449.10
# 10 2018-06-25  Central   Morgan   Pencil     90       4.99   449.10
# 12 2018-07-29     East   Parent   Binder     81      19.99  1619.19
# 17 2018-10-22     East    Jones      Pen     64       8.99   575.36
# 19 2018-11-25  Central   Kivell  Pen Set     96       4.99   479.04
# 20 2018-12-12  Central    Smith   Pencil     67       1.29    86.43
# 21 2018-12-29     East   Parent  Pen Set     74      15.99  1183.26
# 23 2019-02-01  Central    Smith   Binder     87      15.00  1305.00
# 27 2019-04-10  Central  Andrews   Pencil     66       1.99   131.34
# 28 2019-04-27     East   Howard      Pen     96       4.99   479.04
# 30 2019-05-31  Central     Gill   Binder     80       8.99   719.20
# ...

# %%
df[df.A>0]
# Out:
#                    A         B         C         D
# 2012-01-01  0.567307 -2.294988 -0.159050  0.903776
# 2012-01-03  2.014543  0.934096  0.462345 -0.963156
# 2012-01-04  2.062120  0.464300 -1.010371 -0.790814
# 2012-01-06  1.281773  1.294311  1.146546 -0.963617

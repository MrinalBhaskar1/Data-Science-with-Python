# %%
import pandas as pd
import numpy as np

# %%
# Q1). drop the first row from the data set
# Q2). Remove all nan value from the data set
# Q3). Replace '-' with column Mean

# %%
cd
# Out:
# C:\Users\HP

# %%
cd downloads
# Out:
# C:\Users\HP\downloads

# %%
lend=pd.read_excel('Lending Data.xlsx')

# %%
lend.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 14 columns):
# Name of Lending Institution    96 non-null object
# HQ State                       93 non-null object
# Rank                           94 non-null object
# TA Ratio1                      94 non-null object
# TBL Ratio1                     94 non-null object
# Amount ($1,000)                94 non-null object
# Number                         94 non-null object
# Lender Asset Size              94 non-null object
# Amount ($1,000).1              94 non-null float64
# Number .1                      94 non-null float64
# Unnamed: 10                    0 non-null float64
# Amount ($1,000).2              94 non-null float64
# Number .2                      94 non-null float64
# CC Amount/TA1                  94 non-null object
# dtypes: float64(5), object(9)
# memory usage: 10.7+ KB

# %%
lend.shape
# Out:
# (97, 14)

# %%
lend.head()
# Out:
#   Name of Lending Institution HQ State Rank TA Ratio1 TBL Ratio1  \
# 0                         NaN      NaN   -1        -2         -3
# 1       American Express Co.       NY     1   0.23829   0.999544
# 2    First Citizens Banchares      NC     2  0.187393    0.49083
# 3    Wintrust Financial Corp.      IL     3  0.168999   0.383561
# 4               Zions Bancorp      UT     4  0.117973   0.260577
#
#   Amount ($1,000)  Number      Lender Asset Size  Amount ($1,000).1  \
# 0              -4       -5                    -6               -7.0
# 1        16350038  3603226  >$50B                        16318089.0
# 2         3914507   117702  $10B-$50B                      378394.0
# 3         2842793   136801  $10B-$50B                      800526.0
# 4         6231770    52612  >$50B                          526206.0
#
#    Number .1  Unnamed: 10  Amount ($1,000).2  Number .2 CC Amount/TA1
# 0       -8.0          NaN               -9.0      -10.0           -11
# ...

# %%
lend.tail()
# Out:
#                           Name of Lending Institution HQ State Rank TA Ratio1  \
# 92                     Charles Schwab Bk                    NV   NR         -
# 93                     Third FS&LA                          OH   NR         -
# 94  *The bank was formerly known as GE Money Bank,...      NaN  NaN       NaN
# 95  1 TA = total domestic assets held by the lende...      NaN  NaN       NaN
# 96  Source: U.S. Small Business Administration, Of...      NaN  NaN       NaN
#
#    TBL Ratio1 Amount ($1,000) Number      Lender Asset Size  \
# 92          -               -       -  >$10B
# 93          -               -       -  >$10B
# 94        NaN             NaN     NaN                   NaN
# 95        NaN             NaN     NaN                   NaN
# 96        NaN             NaN     NaN                   NaN
#
#     Amount ($1,000).1  Number .1  Unnamed: 10  Amount ($1,000).2  Number .2  \
# 92                0.0        0.0          NaN                0.0        0.0
# ...

# %%
lend.columns
# Out:
# Index(['Name of Lending Institution', 'HQ State', 'Rank', 'TA Ratio1',
#        'TBL Ratio1', 'Amount ($1,000)', 'Number ', 'Lender Asset Size',
#        'Amount ($1,000).1', 'Number .1', 'Unnamed: 10', 'Amount ($1,000).2',
#        'Number .2', 'CC Amount/TA1'],
#       dtype='object')

# %%
del lend['Unnamed: 10']# we are removing this columns because it all contains nan  value and we are data ckenning or asked to remove nan value

# %%
lend.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 13 columns):
# Name of Lending Institution    96 non-null object
# HQ State                       93 non-null object
# Rank                           94 non-null object
# TA Ratio1                      94 non-null object
# TBL Ratio1                     94 non-null object
# Amount ($1,000)                94 non-null object
# Number                         94 non-null object
# Lender Asset Size              94 non-null object
# Amount ($1,000).1              94 non-null float64
# Number .1                      94 non-null float64
# Amount ($1,000).2              94 non-null float64
# Number .2                      94 non-null float64
# CC Amount/TA1                  94 non-null object
# dtypes: float64(4), object(9)
# memory usage: 10.0+ KB

# %%
lend=lend.dropna() # remove all rows with nan value.

# %%
lend.info() # all rows drooped with nan value
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 93 entries, 1 to 93
# Data columns (total 13 columns):
# Name of Lending Institution    93 non-null object
# HQ State                       93 non-null object
# Rank                           93 non-null object
# TA Ratio1                      93 non-null object
# TBL Ratio1                     93 non-null object
# Amount ($1,000)                93 non-null object
# Number                         93 non-null object
# Lender Asset Size              93 non-null object
# Amount ($1,000).1              93 non-null float64
# Number .1                      93 non-null float64
# Amount ($1,000).2              93 non-null float64
# Number .2                      93 non-null float64
# CC Amount/TA1                  93 non-null object
# dtypes: float64(4), object(9)
# memory usage: 10.2+ KB

# %%
lend.shape
# Out:
# (93, 13)

# %%
lend.isnull().sum()
# Out:
# Name of Lending Institution    0
# HQ State                       0
# Rank                           0
# TA Ratio1                      0
# TBL Ratio1                     0
# Amount ($1,000)                0
# Number                         0
# Lender Asset Size              0
# Amount ($1,000).1              0
# Number .1                      0
# Amount ($1,000).2              0
# Number .2                      0
# CC Amount/TA1                  0
# dtype: int64

# %%
lend.head()
# Out:
#   Name of Lending Institution HQ State Rank TA Ratio1 TBL Ratio1  \
# 1       American Express Co.       NY     1   0.23829   0.999544
# 2    First Citizens Banchares      NC     2  0.187393    0.49083
# 3    Wintrust Financial Corp.      IL     3  0.168999   0.383561
# 4               Zions Bancorp      UT     4  0.117973   0.260577
# 5     Synovus Financial Corp.      GA     5  0.162333   0.381387
#
#   Amount ($1,000)  Number      Lender Asset Size  Amount ($1,000).1  \
# 1        16350038  3603226  >$50B                        16318089.0
# 2         3914507   117702  $10B-$50B                      378394.0
# 3         2842793   136801  $10B-$50B                      800526.0
# 4         6231770    52612  >$50B                          526206.0
# 5         4227168    22675  $10B-$50B                      539666.0
#
#    Number .1  Amount ($1,000).2  Number .2 CC Amount/TA1
# 1  3603088.0            31949.0      138.0          0.28
# ...

# %%
lend.tail()
# Out:
#           Name of Lending Institution HQ State Rank TA Ratio1 TBL Ratio1  \
# 89  USAA Svg. Bank                          NV   NR         0          -
# 90                State Street Corp.       MA    NR         -          -
# 91     E Trade Bk                           VA   NR         -          -
# 92     Charles Schwab Bk                    NV   NR         -          -
# 93     Third FS&LA                          OH   NR         -          -
#
#    Amount ($1,000) Number      Lender Asset Size  Amount ($1,000).1  \
# 89               0       1  >$10B                               0.0
# 90               -       -  >$50B                               0.0
# 91               -       -  >$10B                               0.0
# 92               -       -  >$10B                               0.0
# 93               -       -  >$10B                               0.0
#
#     Number .1  Amount ($1,000).2  Number .2 CC Amount/TA1
# 89        1.0                0.0        0.0           .
# ...

# %%
lend=lend.replace('-',np.nan)

# %%
lend.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 93 entries, 1 to 93
# Data columns (total 13 columns):
# Name of Lending Institution    93 non-null object
# HQ State                       93 non-null object
# Rank                           93 non-null object
# TA Ratio1                      89 non-null float64
# TBL Ratio1                     88 non-null float64
# Amount ($1,000)                89 non-null float64
# Number                         89 non-null float64
# Lender Asset Size              93 non-null object
# Amount ($1,000).1              93 non-null float64
# Number .1                      93 non-null float64
# Amount ($1,000).2              93 non-null float64
# Number .2                      93 non-null float64
# CC Amount/TA1                  93 non-null object
# dtypes: float64(8), object(5)
# memory usage: 10.2+ KB

# %%
lend=lend.fillna(lend.mean())

# %%
lend.tail()
# Out:
#           Name of Lending Institution HQ State Rank  TA Ratio1  TBL Ratio1  \
# 89  USAA Svg. Bank                          NV   NR   0.000000    0.251196
# 90                State Street Corp.       MA    NR   0.048668    0.251196
# 91     E Trade Bk                           VA   NR   0.048668    0.251196
# 92     Charles Schwab Bk                    NV   NR   0.048668    0.251196
# 93     Third FS&LA                          OH   NR   0.048668    0.251196
#
#     Amount ($1,000)        Number      Lender Asset Size  Amount ($1,000).1  \
# 89     0.000000e+00       1.000000  >$10B                               0.0
# 90     3.184791e+06  216418.955056  >$50B                               0.0
# 91     3.184791e+06  216418.955056  >$10B                               0.0
# 92     3.184791e+06  216418.955056  >$10B                               0.0
# 93     3.184791e+06  216418.955056  >$10B                               0.0
#
#     Number .1  Amount ($1,000).2  Number .2 CC Amount/TA1
# ...
